# %%
import pandas as pd
import numpy as np
import requests
import pprint as pprint

# %%
COORD_API_KEY = 'LCtFI0n8pug4LgLywn3Osx31p9WYJFaELBFl84pNvVc'
LAT = 35.22286
LNG = -80.83796
SEARCH_RADIU_KM = 100

url = 'https://api.coord.co/v1/sv/location?access_key=' 

query_url = f"{url}{COORD_API_KEY}&latitude={LAT}&longitude={LNG}&radius_km={SEARCH_RADIU_KM}"

response = requests.get(query_url).json()
print(response)
# Out:
# {'features': [{'geometry': {'coordinates': [-80.84509, 35.19034], 'type': 'Point'}, 'id': 'CharlotteBCycle-bcycle_charlotte_2101', 'properties': {'is_renting': True, 'is_returning': True, 'last_reported': '2019-01-12T02:09:10.000Z', 'lat': 35.19034, 'location_id': 'bcycle_charlotte_2101', 'location_type': 'dock', 'lon': -80.84509, 'name': 'Freedom Park', 'num_bikes_available': 12, 'num_docks_available': 10, 'system_id': 'CharlotteBCycle', 'vehicles_available': {'manual_bike': 12}}, 'type': 'Feature'}, {'geometry': {'coordinates': [-80.86884, 35.20028], 'type': 'Point'}, 'id': 'CharlotteBCycle-bcycle_charlotte_2398', 'properties': {'is_renting': True, 'is_returning': True, 'last_reported': '2019-01-12T02:09:10.000Z', 'lat': 35.20028, 'location_id': 'bcycle_charlotte_2398', 'location_type': 'dock', 'lon': -80.86884, 'name': 'New Bern', 'num_bikes_available': 7, 'num_docks_available': 8, 'system_id': 'CharlotteBCycle', 'vehicles_available': {'manual_bike': 7}}, 'type': 'Feature'}, {'geo
# ...
